# %%
#py -3.10 -m venv myvenv
#myvenv\Scripts\activate

# Install the ultralytics package
# %pip install ultralytics torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# %pip install Ultralytics

# Import the YOLO class from ultralytics
from ultralytics import YOLO

# Import torch
import torch # Import the torch module to access its functions

# Load a pre-trained YOLO model
model = YOLO("yolo11n.pt")
# Out:
# Note: you may need to restart the kernel to use updated packages.Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#      ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#      ----------------- ---------------------- 1.8/4.1 MB 11.2 MB/s eta 0:00:01
#      -------------------------------------- - 3.9/4.1 MB 10.7 MB/s eta 0:00:01
#      ---------------------------------------- 4.1/4.1 MB 9.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/2.4 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.4 GB 9.6 MB/s eta 0:04:15
#      ---------------------------------------- 0.0/2.4 GB 9.1 MB/s eta 0:04:28
#      ---------------------------------------- 0.0/2.4 GB 8.9 MB/s eta 0:04:36
#      ---------------------------------------- 0.0/2.4 GB 9.4 MB/s eta 0:04:19
#      ---------------------------------------- 0.0/2.4 GB 9.6 MB/s eta 0:04:15
#      ---------------------------------------- 0.0/2.4 GB 9.9 MB/s eta 0:04:06
# ...

# %%
# Check if CUDA is available and set device accordingly
device = 'cuda' if torch.cuda.is_available() else 'cpu' # Now you can use torch.cuda
print(f"Using device: {device}")


# Train the model on your dataset
train_results = model.train(
    data="D:\Data\PLAY GROUND\my notes\DSAi\Machine Learning\My Models\Object Detection\datasets\LicensePlate_dataset\data.yaml",  # Path to your dataset YAML file
    epochs=5,  # Number of training epochs
    imgsz=640,  # Training image size
    device=device,  # Use the determined device (GPU or CPU)
)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 150    │ │ float64     │ 4     │                                                          │
# │ │ Number of columns │ 6      │ │ int32       │ 1     │                                                          │
# │ └───────────────────┴────────┘ │ string      │ 1     │                                                          │
# ...
